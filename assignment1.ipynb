# %% [markdown]
# <a href="https://colab.research.google.com/github/Schrrodinger/Schrrodinger/blob/main/assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/My Drive
# Out:
# /content/drive/My Drive

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns; sns.set_theme()
from matplotlib.dates import DateFormatter, DayLocator, drange

# %%
df1 = pd.read_csv('/content/drive/MyDrive/2001/2001/k_d_01_2001.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df2 = pd.read_csv('/content/drive/MyDrive/2001/2001/k_d_02_2001.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df3 = pd.read_csv('/content/drive/MyDrive/2001/2001/k_d_03_2001.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df4 = pd.read_csv('/content/drive/MyDrive/2001/2001/k_d_04_2001.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df5 = pd.read_csv('/content/drive/MyDrive/2001/2001/k_d_05_2001.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df6 = pd.read_csv('/content/drive/MyDrive/2001/2001/k_d_06_2001.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df7 = pd.read_csv('/content/drive/MyDrive/2001/2001/k_d_07_2001.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df8 = pd.read_csv('/content/drive/MyDrive/2001/2001/k_d_08_2001.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df9 = pd.read_csv('/content/drive/MyDrive/2001/2001/k_d_09_2001.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df10 = pd.read_csv('/content/drive/MyDrive/2001/2001/k_d_10_2001.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df11= pd.read_csv('/content/drive/MyDrive/2001/2001/k_d_11_2001.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df12= pd.read_csv('/content/drive/MyDrive/2001/2001/k_d_12_2001.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df2001 = pd.concat([df1, df2, df3, df4,df5,df6,df7,df8,df9,df10,df11,df12]).reset_index()
df2001.drop(columns=['TMAX measurement status','index','headerint','TMIN measurement status','STD measurement status','Status "8" no measurement','Status "9" no phenomenon'], inplace=True)

# %%
df13 = pd.read_csv('/content/drive/MyDrive/2002/2002/k_d_01_2002.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df14= pd.read_csv('/content/drive/MyDrive/2002/2002/k_d_02_2002.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df15= pd.read_csv('/content/drive/MyDrive/2002/2002/k_d_03_2002.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df16= pd.read_csv('/content/drive/MyDrive/2002/2002/k_d_04_2002.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df17= pd.read_csv('/content/drive/MyDrive/2002/2002/k_d_05_2002.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df18= pd.read_csv('/content/drive/MyDrive/2002/2002/k_d_06_2002.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df19= pd.read_csv('/content/drive/MyDrive/2002/2002/k_d_07_2002.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df20= pd.read_csv('/content/drive/MyDrive/2002/2002/k_d_08_2002.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df21= pd.read_csv('/content/drive/MyDrive/2002/2002/k_d_09_2002.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df22 = pd.read_csv('/content/drive/MyDrive/2002/2002/k_d_10_2002.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df23= pd.read_csv('/content/drive/MyDrive/2002/2002/k_d_11_2002.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df24= pd.read_csv('/content/drive/MyDrive/2002/2002/k_d_12_2002.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df2002 = pd.concat([df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24]).reset_index()
df2002.drop(columns=['TMAX measurement status','index','headerint','TMIN measurement status','STD measurement status','Status "8" no measurement','Status "9" no phenomenon'], inplace=True)

# %%
df25 = pd.read_csv('/content/drive/MyDrive/2003/2003/k_d_01_2003.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df26= pd.read_csv('/content/drive/MyDrive/2003/2003/k_d_02_2003.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df27= pd.read_csv('/content/drive/MyDrive/2003/2003/k_d_03_2003.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df28= pd.read_csv('/content/drive/MyDrive/2003/2003/k_d_04_2003.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df29= pd.read_csv('/content/drive/MyDrive/2003/2003/k_d_05_2003.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df30= pd.read_csv('/content/drive/MyDrive/2003/2003/k_d_06_2003.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df31= pd.read_csv('/content/drive/MyDrive/2003/2003/k_d_07_2003.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df32= pd.read_csv('/content/drive/MyDrive/2003/2003/k_d_08_2003.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df33= pd.read_csv('/content/drive/MyDrive/2003/2003/k_d_09_2003.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df34 = pd.read_csv('/content/drive/MyDrive/2003/2003/k_d_10_2003.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df35= pd.read_csv('/content/drive/MyDrive/2003/2003/k_d_11_2003.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df36= pd.read_csv('/content/drive/MyDrive/2003/2003/k_d_12_2003.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df2003 = pd.concat([df25,df26,df27,df28,df29,df30,df31,df32,df33,df34,df35,df36]).reset_index()
df2003.drop(columns=['TMAX measurement status','index','headerint','TMIN measurement status','STD measurement status','Status "8" no measurement','Status "9" no phenomenon'], inplace=True)

# %%
df37 = pd.read_csv('/content/drive/MyDrive/2004/2004/k_d_01_2004.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df38= pd.read_csv('/content/drive/MyDrive/2004/2004/k_d_02_2004.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df39= pd.read_csv('/content/drive/MyDrive/2004/2004/k_d_03_2004.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df40= pd.read_csv('/content/drive/MyDrive/2004/2004/k_d_04_2004.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df41= pd.read_csv('/content/drive/MyDrive/2004/2004/k_d_05_2004.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df42= pd.read_csv('/content/drive/MyDrive/2004/2004/k_d_06_2004.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df43= pd.read_csv('/content/drive/MyDrive/2004/2004/k_d_07_2004.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df44= pd.read_csv('/content/drive/MyDrive/2004/2004/k_d_08_2004.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df45= pd.read_csv('/content/drive/MyDrive/2004/2004/k_d_09_2004.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df46 = pd.read_csv('/content/drive/MyDrive/2004/2004/k_d_10_2004.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df47= pd.read_csv('/content/drive/MyDrive/2004/2004/k_d_11_2004.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df48= pd.read_csv('/content/drive/MyDrive/2004/2004/k_d_12_2004.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df2004 = pd.concat([df37,df38,df39,df40,df41,df42,df43,df44,df45,df46,df47,df48]).reset_index()
df2004.drop(columns=['TMAX measurement status','index','headerint','TMIN measurement status','STD measurement status','Status "8" no measurement','Status "9" no phenomenon'], inplace=True)

# %%
df49= pd.read_csv('/content/drive/MyDrive/2005/2005/k_d_01_2005.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df50= pd.read_csv('/content/drive/MyDrive/2005/2005/k_d_02_2005.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df51= pd.read_csv('/content/drive/MyDrive/2005/2005/k_d_03_2005.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df52= pd.read_csv('/content/drive/MyDrive/2005/2005/k_d_04_2005.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df53= pd.read_csv('/content/drive/MyDrive/2005/2005/k_d_05_2005.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df54= pd.read_csv('/content/drive/MyDrive/2005/2005/k_d_06_2005.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df55= pd.read_csv('/content/drive/MyDrive/2005/2005/k_d_07_2005.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df56= pd.read_csv('/content/drive/MyDrive/2005/2005/k_d_08_2005.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df57= pd.read_csv('/content/drive/MyDrive/2005/2005/k_d_09_2005.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df58 = pd.read_csv('/content/drive/MyDrive/2005/2005/k_d_10_2005.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df59= pd.read_csv('/content/drive/MyDrive/2005/2005/k_d_11_2005.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df60= pd.read_csv('/content/drive/MyDrive/2005/2005/k_d_12_2005.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df2005 = pd.concat([df49,df50,df51,df52,df53,df54,df55,df56,df57,df58,df59,df60]).reset_index()
df2005.drop(columns=['TMAX measurement status','index','headerint','TMIN measurement status','STD measurement status','Status "8" no measurement','Status "9" no phenomenon'], inplace=True)

# %%
df61= pd.read_csv('/content/drive/MyDrive/2006/2006/k_d_01_2006.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df62= pd.read_csv('/content/drive/MyDrive/2006/2006/k_d_02_2006.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df63= pd.read_csv('/content/drive/MyDrive/2006/2006/k_d_03_2006.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df64= pd.read_csv('/content/drive/MyDrive/2006/2006/k_d_04_2006.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df65= pd.read_csv('/content/drive/MyDrive/2006/2006/k_d_05_2006.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df66= pd.read_csv('/content/drive/MyDrive/2006/2006/k_d_06_2006.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df67= pd.read_csv('/content/drive/MyDrive/2006/2006/k_d_07_2006.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df68= pd.read_csv('/content/drive/MyDrive/2006/2006/k_d_08_2006.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df69= pd.read_csv('/content/drive/MyDrive/2006/2006/k_d_09_2006.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df70 = pd.read_csv('/content/drive/MyDrive/2006/2006/k_d_10_2006.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df71= pd.read_csv('/content/drive/MyDrive/2006/2006/k_d_11_2006.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df72= pd.read_csv('/content/drive/MyDrive/2006/2006/k_d_12_2006.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df2006 = pd.concat([df61,df62,df63,df64,df65,df66,df67,df68,df69,df70,df71,df72]).reset_index()
df2006.drop(columns=['TMAX measurement status','index','headerint','TMIN measurement status','STD measurement status','Status "8" no measurement','Status "9" no phenomenon'], inplace=True)

# %%
df73= pd.read_csv('/content/drive/MyDrive/2007/2007/k_d_01_2007.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df74= pd.read_csv('/content/drive/MyDrive/2007/2007/k_d_02_2007.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df75= pd.read_csv('/content/drive/MyDrive/2007/2007/k_d_03_2007.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df76= pd.read_csv('/content/drive/MyDrive/2007/2007/k_d_04_2007.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df77= pd.read_csv('/content/drive/MyDrive/2007/2007/k_d_05_2007.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df78= pd.read_csv('/content/drive/MyDrive/2007/2007/k_d_06_2007.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df79= pd.read_csv('/content/drive/MyDrive/2007/2007/k_d_07_2007.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df80= pd.read_csv('/content/drive/MyDrive/2007/2007/k_d_08_2007.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df81= pd.read_csv('/content/drive/MyDrive/2007/2007/k_d_09_2007.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df82 = pd.read_csv('/content/drive/MyDrive/2007/2007/k_d_10_2007.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df83= pd.read_csv('/content/drive/MyDrive/2007/2007/k_d_11_2007.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df84= pd.read_csv('/content/drive/MyDrive/2007/2007/k_d_12_2007.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df2007 = pd.concat([df73,df74,df75,df76,df77,df78,df79,df80,df81,df82,df83,df84]).reset_index()
df2007.drop(columns=['TMAX measurement status','index','headerint','TMIN measurement status','STD measurement status','Status "8" no measurement','Status "9" no phenomenon'], inplace=True)

# %%
df85= pd.read_csv('/content/drive/MyDrive/2008/2008/k_d_01_2008.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df86= pd.read_csv('/content/drive/MyDrive/2008/2008/k_d_02_2008.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df87= pd.read_csv('/content/drive/MyDrive/2008/2008/k_d_03_2008.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df88= pd.read_csv('/content/drive/MyDrive/2008/2008/k_d_04_2008.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df89= pd.read_csv('/content/drive/MyDrive/2008/2008/k_d_05_2008.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df90= pd.read_csv('/content/drive/MyDrive/2008/2008/k_d_06_2008.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df91= pd.read_csv('/content/drive/MyDrive/2008/2008/k_d_07_2008.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df92= pd.read_csv('/content/drive/MyDrive/2008/2008/k_d_08_2008.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df93= pd.read_csv('/content/drive/MyDrive/2008/2008/k_d_09_2008.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df94 = pd.read_csv('/content/drive/MyDrive/2008/2008/k_d_10_2008.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df95= pd.read_csv('/content/drive/MyDrive/2008/2008/k_d_11_2008.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df96= pd.read_csv('/content/drive/MyDrive/2008/2008/k_d_12_2008.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df2008 = pd.concat([df85,df86,df87,df88,df89,df90,df91,df92,df93,df94,df95,df96]).reset_index()
df2008.drop(columns=['TMAX measurement status','index','headerint','TMIN measurement status','STD measurement status','Status "8" no measurement','Status "9" no phenomenon'], inplace=True)

# %%
df97= pd.read_csv('/content/drive/MyDrive/2009/2009/k_d_01_2009.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df98= pd.read_csv('/content/drive/MyDrive/2009/2009/k_d_02_2009.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df99= pd.read_csv('/content/drive/MyDrive/2009/2009/k_d_03_2009.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df100= pd.read_csv('/content/drive/MyDrive/2009/2009/k_d_04_2009.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df101= pd.read_csv('/content/drive/MyDrive/2009/2009/k_d_05_2009.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df102= pd.read_csv('/content/drive/MyDrive/2009/2009/k_d_06_2009.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df103= pd.read_csv('/content/drive/MyDrive/2009/2009/k_d_07_2009.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df104= pd.read_csv('/content/drive/MyDrive/2009/2009/k_d_08_2009.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df105= pd.read_csv('/content/drive/MyDrive/2009/2009/k_d_09_2009.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df106 = pd.read_csv('/content/drive/MyDrive/2009/2009/k_d_10_2009.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df107= pd.read_csv('/content/drive/MyDrive/2009/2009/k_d_11_2009.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df108= pd.read_csv('/content/drive/MyDrive/2009/2009/k_d_12_2009.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df2009 = pd.concat([df97,df98,df99,df100,df101,df102,df103,df104,df105,df106,df107,df108]).reset_index()
df2009.drop(columns=['TMAX measurement status','index','headerint','TMIN measurement status','STD measurement status','Status "8" no measurement','Status "9" no phenomenon'], inplace=True)

# %%
df109= pd.read_csv('/content/drive/MyDrive/2010/2010/k_d_01_2010.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df110= pd.read_csv('/content/drive/MyDrive/2010/2010/k_d_02_2010.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df111= pd.read_csv('/content/drive/MyDrive/2010/2010/k_d_03_2010.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df112= pd.read_csv('/content/drive/MyDrive/2010/2010/k_d_04_2010.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df113= pd.read_csv('/content/drive/MyDrive/2010/2010/k_d_05_2010.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df114= pd.read_csv('/content/drive/MyDrive/2010/2010/k_d_06_2010.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df115= pd.read_csv('/content/drive/MyDrive/2010/2010/k_d_07_2010.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df116= pd.read_csv('/content/drive/MyDrive/2010/2010/k_d_08_2010.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df117= pd.read_csv('/content/drive/MyDrive/2010/2010/k_d_09_2010.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df118 = pd.read_csv('/content/drive/MyDrive/2010/2010/k_d_10_2010.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df119= pd.read_csv('/content/drive/MyDrive/2010/2010/k_d_11_2010.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df120= pd.read_csv('/content/drive/MyDrive/2010/2010/k_d_12_2010.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df2010 = pd.concat([df109,df110,df111,df112,df113,df114,df115,df116,df117,df118,df119,df120]).reset_index()
df2010.drop(columns=['TMAX measurement status','index','headerint','TMIN measurement status','STD measurement status','Status "8" no measurement','Status "9" no phenomenon'], inplace=True)

# %%
df121= pd.read_csv('/content/drive/MyDrive/2011/2011/k_d_01_2011.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df122= pd.read_csv('/content/drive/MyDrive/2011/2011/k_d_02_2011.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df123= pd.read_csv('/content/drive/MyDrive/2011/2011/k_d_03_2011.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df124= pd.read_csv('/content/drive/MyDrive/2011/2011/k_d_04_2011.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df125= pd.read_csv('/content/drive/MyDrive/2011/2011/k_d_05_2011.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df126= pd.read_csv('/content/drive/MyDrive/2011/2011/k_d_06_2011.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df127= pd.read_csv('/content/drive/MyDrive/2011/2011/k_d_07_2011.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df128= pd.read_csv('/content/drive/MyDrive/2011/2011/k_d_08_2011.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df129= pd.read_csv('/content/drive/MyDrive/2011/2011/k_d_09_2011.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df130 = pd.read_csv('/content/drive/MyDrive/2011/2011/k_d_10_2011.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df131= pd.read_csv('/content/drive/MyDrive/2011/2011/k_d_11_2011.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df132= pd.read_csv('/content/drive/MyDrive/2011/2011/k_d_12_2011.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df2011 = pd.concat([df121,df122,df123,df124,df125,df126,df127,df128,df129,df130,df131,df132]).reset_index()
df2011.drop(columns=['TMAX measurement status','index','headerint','TMIN measurement status','STD measurement status','Status "8" no measurement','Status "9" no phenomenon'], inplace=True)

# %%
df133= pd.read_csv('/content/drive/MyDrive/2012/2012/k_d_01_2012.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df134= pd.read_csv('/content/drive/MyDrive/2012/2012/k_d_02_2012.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df135= pd.read_csv('/content/drive/MyDrive/2012/2012/k_d_03_2012.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df136= pd.read_csv('/content/drive/MyDrive/2012/2012/k_d_04_2012.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df137= pd.read_csv('/content/drive/MyDrive/2012/2012/k_d_05_2012.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df138= pd.read_csv('/content/drive/MyDrive/2012/2012/k_d_06_2012.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df139= pd.read_csv('/content/drive/MyDrive/2012/2012/k_d_07_2012.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df140= pd.read_csv('/content/drive/MyDrive/2012/2012/k_d_08_2012.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df141= pd.read_csv('/content/drive/MyDrive/2012/2012/k_d_09_2012.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df142 = pd.read_csv('/content/drive/MyDrive/2012/2012/k_d_10_2012.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df143= pd.read_csv('/content/drive/MyDrive/2012/2012/k_d_11_2012.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df144= pd.read_csv('/content/drive/MyDrive/2012/2012/k_d_12_2012.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df2012 = pd.concat([df133,df134,df135,df136,df137,df138,df139,df140,df141,df142,df143,df144]).reset_index()
df2012.drop(columns=['TMAX measurement status','index','headerint','TMIN measurement status','STD measurement status','Status "8" no measurement','Status "9" no phenomenon'], inplace=True)

# %%
df145= pd.read_csv('/content/drive/MyDrive/2013/2013/k_d_01_2013.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df146= pd.read_csv('/content/drive/MyDrive/2013/2013/k_d_02_2013.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df147= pd.read_csv('/content/drive/MyDrive/2013/2013/k_d_03_2013.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df148= pd.read_csv('/content/drive/MyDrive/2013/2013/k_d_04_2013.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df149= pd.read_csv('/content/drive/MyDrive/2013/2013/k_d_05_2013.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df150= pd.read_csv('/content/drive/MyDrive/2013/2013/k_d_06_2013.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df151= pd.read_csv('/content/drive/MyDrive/2010/2010/k_d_07_2010.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df152= pd.read_csv('/content/drive/MyDrive/2013/2013/k_d_08_2013.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df153= pd.read_csv('/content/drive/MyDrive/2013/2013/k_d_09_2013.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df154 = pd.read_csv('/content/drive/MyDrive/2013/2013/k_d_10_2013.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df155= pd.read_csv('/content/drive/MyDrive/2013/2013/k_d_11_2013.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df156= pd.read_csv('/content/drive/MyDrive/2013/2013/k_d_12_2013.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df2013 = pd.concat([df145,df146,df147,df148,df149,df150,df151,df152,df153,df154,df155,df156]).reset_index()
df2013.drop(columns=['TMAX measurement status','index','headerint','TMIN measurement status','STD measurement status','Status "8" no measurement','Status "9" no phenomenon'], inplace=True)

# %%
df157= pd.read_csv('/content/drive/MyDrive/2014/2014/k_d_01_2014.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df158= pd.read_csv('/content/drive/MyDrive/2014/2014/k_d_02_2014.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df159= pd.read_csv('/content/drive/MyDrive/2014/2014/k_d_03_2014.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df160= pd.read_csv('/content/drive/MyDrive/2014/2014/k_d_04_2014.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df161= pd.read_csv('/content/drive/MyDrive/2014/2014/k_d_05_2014.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df162= pd.read_csv('/content/drive/MyDrive/2014/2014/k_d_06_2014.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df163= pd.read_csv('/content/drive/MyDrive/2014/2014/k_d_07_2014.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df164= pd.read_csv('/content/drive/MyDrive/2014/2014/k_d_08_2014.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df165= pd.read_csv('/content/drive/MyDrive/2014/2014/k_d_09_2014.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df166 = pd.read_csv('/content/drive/MyDrive/2014/2014/k_d_10_2014.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df167= pd.read_csv('/content/drive/MyDrive/2014/2014/k_d_11_2014.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df168= pd.read_csv('/content/drive/MyDrive/2014/2014/k_d_12_2014.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df2014 = pd.concat([df157,df158,df159,df160,df161,df162,df163,df164,df165,df166,df167,df168]).reset_index()
df2014.drop(columns=['TMAX measurement status','index','headerint','TMIN measurement status','STD measurement status','Status "8" no measurement','Status "9" no phenomenon'], inplace=True)

# %%
df169= pd.read_csv('/content/drive/MyDrive/2015/2015/k_d_01_2015.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df170= pd.read_csv('/content/drive/MyDrive/2015/2015/k_d_02_2015.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df171= pd.read_csv('/content/drive/MyDrive/2015/2015/k_d_03_2015.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df172= pd.read_csv('/content/drive/MyDrive/2015/2015/k_d_04_2015.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df173= pd.read_csv('/content/drive/MyDrive/2015/2015/k_d_05_2015.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df174= pd.read_csv('/content/drive/MyDrive/2015/2015/k_d_06_2015.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df175= pd.read_csv('/content/drive/MyDrive/2015/2015/k_d_07_2015.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df176= pd.read_csv('/content/drive/MyDrive/2015/2015/k_d_08_2015.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df177= pd.read_csv('/content/drive/MyDrive/2015/2015/k_d_09_2015.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df178 = pd.read_csv('/content/drive/MyDrive/2015/2015/k_d_10_2015.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df179= pd.read_csv('/content/drive/MyDrive/2015/2015/k_d_11_2015.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df180= pd.read_csv('/content/drive/MyDrive/2015/2015/k_d_12_2015.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df2015 = pd.concat([df169,df170,df171,df172,df173,df174,df175,df176,df177,df178,df179,df180]).reset_index()
df2015.drop(columns=['TMAX measurement status','index','headerint','TMIN measurement status','STD measurement status','Status "8" no measurement','Status "9" no phenomenon'], inplace=True)

# %%
df181= pd.read_csv('/content/drive/MyDrive/2016/2016/k_d_01_2016.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df182= pd.read_csv('/content/drive/MyDrive/2016/2016/k_d_02_2016.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df183= pd.read_csv('/content/drive/MyDrive/2016/2016/k_d_03_2016.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df184= pd.read_csv('/content/drive/MyDrive/2016/2016/k_d_04_2016.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df185= pd.read_csv('/content/drive/MyDrive/2016/2016/k_d_05_2016.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df186= pd.read_csv('/content/drive/MyDrive/2016/2016/k_d_06_2016.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df187= pd.read_csv('/content/drive/MyDrive/2016/2016/k_d_07_2016.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df188= pd.read_csv('/content/drive/MyDrive/2016/2016/k_d_08_2016.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df189= pd.read_csv('/content/drive/MyDrive/2016/2016/k_d_09_2016.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df190 = pd.read_csv('/content/drive/MyDrive/2016/2016/k_d_10_2016.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df191= pd.read_csv('/content/drive/MyDrive/2016/2016/k_d_11_2016.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df192= pd.read_csv('/content/drive/MyDrive/2016/2016/k_d_12_2016.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df2016 = pd.concat([df181,df182,df183,df184,df185,df186,df187,df188,df189,df190,df191,df192]).reset_index()
df2016.drop(columns=['TMAX measurement status','index','headerint','TMIN measurement status','STD measurement status','Status "8" no measurement','Status "9" no phenomenon'], inplace=True)

# %%
df193= pd.read_csv('/content/drive/MyDrive/2017/2017/k_d_01_2017.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df194= pd.read_csv('/content/drive/MyDrive/2017/2017/k_d_02_2017.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df195= pd.read_csv('/content/drive/MyDrive/2017/2017/k_d_03_2017.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df196= pd.read_csv('/content/drive/MyDrive/2017/2017/k_d_04_2017.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df197= pd.read_csv('/content/drive/MyDrive/2017/2017/k_d_05_2017.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df198= pd.read_csv('/content/drive/MyDrive/2017/2017/k_d_06_2017.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df199= pd.read_csv('/content/drive/MyDrive/2017/2017/k_d_07_2017.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df200= pd.read_csv('/content/drive/MyDrive/2017/2017/k_d_08_2017.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df201= pd.read_csv('/content/drive/MyDrive/2017/2017/k_d_09_2017.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df202 = pd.read_csv('/content/drive/MyDrive/2017/2017/k_d_10_2017.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df203= pd.read_csv('/content/drive/MyDrive/2017/2017/k_d_11_2017.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df204= pd.read_csv('/content/drive/MyDrive/2017/2017/k_d_12_2017.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df2017 = pd.concat([df193,df194,df195,df196,df197,df198,df199,df200,df201,df202,df203,df204]).reset_index()
df2017.drop(columns=['TMAX measurement status','index','headerint','TMIN measurement status','STD measurement status','Status "8" no measurement','Status "9" no phenomenon'], inplace=True)

# %%
df205= pd.read_csv('/content/drive/MyDrive/2018/2018/k_d_01_2018.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df206= pd.read_csv('/content/drive/MyDrive/2018/2018/k_d_02_2018.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df207= pd.read_csv('/content/drive/MyDrive/2018/2018/k_d_03_2018.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df208= pd.read_csv('/content/drive/MyDrive/2018/2018/k_d_04_2018.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df209= pd.read_csv('/content/drive/MyDrive/2018/2018/k_d_05_2018.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df210= pd.read_csv('/content/drive/MyDrive/2018/2018/k_d_06_2018.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df211= pd.read_csv('/content/drive/MyDrive/2018/2018/k_d_07_2018.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df212= pd.read_csv('/content/drive/MyDrive/2018/2018/k_d_08_2018.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df213= pd.read_csv('/content/drive/MyDrive/2018/2018/k_d_09_2018.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df214 = pd.read_csv('/content/drive/MyDrive/2018/2018/k_d_10_2018.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df215= pd.read_csv('/content/drive/MyDrive/2018/2018/k_d_11_2018.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df216= pd.read_csv('/content/drive/MyDrive/2018/2018/k_d_12_2018.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df2018 = pd.concat([df205,df206,df207,df208,df209,df210,df211,df212,df213,df214,df215,df216]).reset_index()
df2018.drop(columns=['TMAX measurement status','index','headerint','TMIN measurement status','STD measurement status','Status "8" no measurement','Status "9" no phenomenon'], inplace=True)

# %%
df217= pd.read_csv('/content/drive/MyDrive/2019/2019/k_d_01_2019.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df218= pd.read_csv('/content/drive/MyDrive/2019/2019/k_d_02_2019.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df219= pd.read_csv('/content/drive/MyDrive/2019/2019/k_d_03_2019.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df220= pd.read_csv('/content/drive/MyDrive/2019/2019/k_d_04_2019.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df221= pd.read_csv('/content/drive/MyDrive/2019/2019/k_d_05_2019.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df222= pd.read_csv('/content/drive/MyDrive/2019/2019/k_d_06_2019.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df223= pd.read_csv('/content/drive/MyDrive/2019/2019/k_d_07_2019.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df224= pd.read_csv('/content/drive/MyDrive/2019/2019/k_d_08_2019.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df225= pd.read_csv('/content/drive/MyDrive/2019/2019/k_d_09_2019.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df226 = pd.read_csv('/content/drive/MyDrive/2019/2019/k_d_10_2019.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df227= pd.read_csv('/content/drive/MyDrive/2019/2019/k_d_11_2019.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df228= pd.read_csv('/content/drive/MyDrive/2019/2019/k_d_12_2019.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df2019 = pd.concat([df217,df218,df219,df220,df221,df222,df223,df224,df225,df226,df227,df228]).reset_index()
df2019.drop(columns=['TMAX measurement status','index','headerint','TMIN measurement status','STD measurement status','Status "8" no measurement','Status "9" no phenomenon'], inplace=True)

# %%
df229= pd.read_csv('/content/drive/MyDrive/2020/2020/k_d_01_2020.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df230= pd.read_csv('/content/drive/MyDrive/2020/2020/k_d_02_2020.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df231= pd.read_csv('/content/drive/MyDrive/2020/2020/k_d_03_2020.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df232= pd.read_csv('/content/drive/MyDrive/2020/2020/k_d_04_2020.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df233= pd.read_csv('/content/drive/MyDrive/2020/2020/k_d_05_2020.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df234= pd.read_csv('/content/drive/MyDrive/2020/2020/k_d_06_2020.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df235= pd.read_csv('/content/drive/MyDrive/2020/2020/k_d_07_2020.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df236= pd.read_csv('/content/drive/MyDrive/2020/2020/k_d_08_2020.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df237= pd.read_csv('/content/drive/MyDrive/2020/2020/k_d_09_2020.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                         'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df238 = pd.read_csv('/content/drive/MyDrive/2020/2020/k_d_10_2020.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df239= pd.read_csv('/content/drive/MyDrive/2020/2020/k_d_11_2020.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df240= pd.read_csv('/content/drive/MyDrive/2020/2020/k_d_12_2020.csv', sep=",", encoding='cp1252' , names=['headerint','Station name','Year','Month','Day','Maximum daily temperature [° C]','TMAX measurement status',
                                                                          'Minimum daily temperature [° C]','TMIN measurement status','Average daily temperature [° C]','STD measurement status',
                                                                          'Minimum temperature at the ground [° C]','TMNG measurement status','Daily sum of precipitation [mm]','SMDB measurement status',
                                                                         'Type of precipitation [S / W /]','Snow cover height [cm]','PKSN measurement status','Status "8" no measurement','Status "9" no phenomenon'])
df2020 = pd.concat([df229,df230,df231,df232,df233,df234,df235,df236,df237,df238,df239,df240]).reset_index()
df2020.drop(columns=['TMAX measurement status','index','headerint','TMIN measurement status','STD measurement status','Status "8" no measurement','Status "9" no phenomenon'], inplace=True)

# %%
df=pd.concat([df2001,df2002,df2003,df2004,df2005,df2006,df2007,df2008,df2009,df2010,df2011,df2012,df2013,df2014,df2015,df2016,df2017,df2018,df2019,df2020]).reset_index()

# %%
df.head()
# Out:
#    index Station name  Year  Month  Day  Maximum daily temperature [° C]  \
# 0      0     PSZCZYNA  2001      1    1                             -1.3
# 1      1     PSZCZYNA  2001      1    2                              3.3
# 2      2     PSZCZYNA  2001      1    3                              1.5
# 3      3     PSZCZYNA  2001      1    4                              6.5
# 4      4     PSZCZYNA  2001      1    5                              6.5
#
#    Minimum daily temperature [° C]  Average daily temperature [° C]  \
# 0                             -9.6                             -5.7
# 1                            -12.0                             -2.7
# 2                             -5.7                             -1.5
# 3                             -1.1                              1.9
# 4                             -2.3                              2.8
#
#    Minimum temperature at the ground [° C]  TMNG measurement status  \
# ...

# %%
df['Year'] = df['Year'].astype(str)
df['Day'] = df['Day'].astype(str)
df['Month'] = df['Month'].astype(str)
df['Date'] = df['Year']+'/'+df['Month']+'/'+df['Day']
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')
df.drop(columns=['Year','Day','Month'], inplace=True)

# %%
df['Date'].head
# Out:
# <bound method NDFrame.head of 0        2001-01-01
# 1        2001-01-02
# 2        2001-01-03
# 3        2001-01-04
# 4        2001-01-05
#             ...
# 969709   2020-12-27
# 969710   2020-12-28
# 969711   2020-12-29
# 969712   2020-12-30
# 969713   2020-12-31
# Name: Date, Length: 969714, dtype: datetime64[ns]>

# %%
df.head()
# Out:
#    index Station name  Maximum daily temperature [° C]  \
# 0      0     PSZCZYNA                             -1.3
# 1      1     PSZCZYNA                              3.3
# 2      2     PSZCZYNA                              1.5
# 3      3     PSZCZYNA                              6.5
# 4      4     PSZCZYNA                              6.5
#
#    Minimum daily temperature [° C]  Average daily temperature [° C]  \
# 0                             -9.6                             -5.7
# 1                            -12.0                             -2.7
# 2                             -5.7                             -1.5
# 3                             -1.1                              1.9
# 4                             -2.3                              2.8
#
#    Minimum temperature at the ground [° C]  TMNG measurement status  \
# 0                                    -11.0                      NaN
# 1                                    -13.2                      NaN
# ...

# %%
a = df[df['Station name']=='PSZCZYNA']
a.head()
# Out:
#    index Station name  Maximum daily temperature [° C]  \
# 0      0     PSZCZYNA                             -1.3
# 1      1     PSZCZYNA                              3.3
# 2      2     PSZCZYNA                              1.5
# 3      3     PSZCZYNA                              6.5
# 4      4     PSZCZYNA                              6.5
#
#    Minimum daily temperature [° C]  Average daily temperature [° C]  \
# 0                             -9.6                             -5.7
# 1                            -12.0                             -2.7
# 2                             -5.7                             -1.5
# 3                             -1.1                              1.9
# 4                             -2.3                              2.8
#
#    Minimum temperature at the ground [° C]  TMNG measurement status  \
# 0                                    -11.0                      NaN
# 1                                    -13.2                      NaN
# ...

# %%
len(a['Station name'].unique())
# Out:
# 1

# %%
b = df.drop(columns='Station name')
b = df.groupby(['Date']).quantile(q=0.75)
b.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping invalid columns in DataFrameGroupBy.quantile is deprecated. In a future version, a TypeError will be raised. Before calling .quantile, select only columns which should be valid for the function.
#              index  Maximum daily temperature [° C]  \
# Date
# 2001-01-01  3673.5                             0.60
# 2001-01-02  3674.5                             2.40
# 2001-01-03  3675.5                             3.45
# 2001-01-04  3676.5                             5.45
# 2001-01-05  3677.5                             5.50
#
#             Minimum daily temperature [° C]  Average daily temperature [° C]  \
# Date
# 2001-01-01                            -4.55                            -2.55
# 2001-01-02                            -4.00                            -0.40
# 2001-01-03                            -0.45                             1.20
# ...

# %%
plt.rc('font', size=12)
fig, axes = plt.subplots(figsize=(10,6));

# Set plot line width
line_width = 1.5

# Plot data
axes.plot(b['Average daily temperature [° C]'].index, b['Average daily temperature [° C]'], color='tab:purple', label='Average temperature')
axes.plot(b['Maximum daily temperature [° C]'].index, b['Maximum daily temperature [° C]'], color='tab:red', label='Max temperature')
axes.plot(b['Maximum daily temperature [° C]'].index, b['Minimum daily temperature [° C]'], color='tab:blue', label='Min temperature')


# Set figure title
fig.suptitle('2001-2020 Seasonal temperature observations - Poland')


# Axis labels
axes.set_xlabel('Date')
axes.set_title('Temperature')
axes.set_ylabel('Temperature [°C]')
axes.grid(True)
axes.legend(loc='upper left')


fig.autofmt_xdate(rotation=45)
plt.show()
